# %%
x=5
y="john"
print(x)
print(y)
# Out:
# 5
# john

# %%
x=4
x="sally"
print(x)
# Out:
# sally

# %%
x=str(3)
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x=5
y="john"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=4
A="sally"
print(a)
print(A)
# Out:
# 4
# sally

# %%
x,y,z="orange","banana","cherry"
print(x)
print(y)
print(z)
# Out:
# orange
# banana
# cherry

# %%
x="python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# python is awesome

# %%
x=5
print(type(x))
print(x)
# Out:
# <class 'int'>
# 5

# %%
x=1
y=2.8
z=1j
print(type(x))
print(type(y))
print(type(z)
)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
x=1
y=3565647383764
z=3264843
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x=1.10
y=1.0
z=-35.59
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x=3+5j
y=5j
z=5j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x=1
y=2.8
z=1j
a=float(x)
b=int(y)
c=complex(x)
print(a)
print(b)
print(c)
# Out:
# 1.0
# 2
# (1+0j)

# %%
x=int(1)
y=int(2.8)
z=int("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x=float(1)
y=float(2.8)
z=float("3")
w=float("4.3")
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.8
# 3.0
# 4.3

# %%
x=str("s1")
y=str(2)
z=str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a="Hello"
print(a)
# Out:
# Hello

# %%
a="""Lorem ipsum dolor sit amet,consector adipiscing elit,sed do eiusmod tempor incidint at labore eet dolor magna aliqyua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,consector adipiscing elit,sed do eiusmod tempor incidint at labore eet dolor magna aliqyua.

# %%
a="hello,world"
print(a[1])
# Out:
# e

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a="hello,world"
print(len(a))
# Out:
# 11

# %%
txt="the best things in life are free!"
if"free"in txt:
  print("yes,'free'is present")
# Out:
# yes,'free'is present

# %%
txt="the best things in life are free!"
print("expensive"not in txt)
# Out:
# True

# %%
b="hello,world!"
print(b[2:5])
# Out:
# llo

# %%
a=b="hello,world!"
print(b[:5])
print(b[2:])
print(b[-5:-2])
print(a.upper())
print(a.lower())
# Out:
# hello
# llo,world!
# orl
# HELLO,WORLD!
# hello,world!

# %%
a="hello,world!"
print(a.strip())
print(a.replace("H","j"))
print(a.split(","))
# Out:
# hello,world!
# hello,world!
# ['hello', 'world!']

# %%
a="Hello"
b="world"
c=a+b
print(c)
# Out:
# Helloworld

# %%
  print(10>9)
  print(10==9)
  print(10<9)
# Out:
# True
# False
# False

# %%
a=200
b=33
if b>a:
  print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a
