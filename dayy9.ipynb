# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
# %matplotlib inline

# %%
df=pd.read_csv('pharma dataset.python.csv')

# %%
df
# Out:
#                    Distributor                               Customer Name  \
# 0       Gottlieb-Cruickshank                       Zieme, Doyle and Kunze
# 1       Gottlieb-Cruickshank                                    Feest PLC
# 2       Gottlieb-Cruickshank          Medhurst-Beer Pharmaceutical Limited
# 3       Gottlieb-Cruickshank                         Barton Ltd Pharma Plc
# 4       Gottlieb-Cruickshank                          Keeling LLC Pharmacy
# ...                        ...                                         ...
# 253404    Bashirian-Kassulke    Koch, Borer and Hagenes Pharmaceutical Ltd
# 253405    Bashirian-Kassulke                   Hane Ltd Pharmaceutical Ltd
# 253406    Bashirian-Kassulke                        Harris-Conroy Pharmacy
# 253407    Bashirian-Kassulke                        Balistreri Group Pharm
# 253408    Bashirian-Kassulke                Heathcote, Kovacek and Parker
#
# ...

# %%
df.rename(columns={'Distributor':'Supplier','Customer Name':'customer name','City':'city','Country':'country'},inplace=True)

# %%
df
# Out:
#                       Supplier                               customer name  \
# 0       Gottlieb-Cruickshank                       Zieme, Doyle and Kunze
# 1       Gottlieb-Cruickshank                                    Feest PLC
# 2       Gottlieb-Cruickshank          Medhurst-Beer Pharmaceutical Limited
# 3       Gottlieb-Cruickshank                         Barton Ltd Pharma Plc
# 4       Gottlieb-Cruickshank                          Keeling LLC Pharmacy
# ...                        ...                                         ...
# 253404    Bashirian-Kassulke    Koch, Borer and Hagenes Pharmaceutical Ltd
# 253405    Bashirian-Kassulke                   Hane Ltd Pharmaceutical Ltd
# 253406    Bashirian-Kassulke                        Harris-Conroy Pharmacy
# 253407    Bashirian-Kassulke                        Balistreri Group Pharm
# 253408    Bashirian-Kassulke                Heathcote, Kovacek and Parker
#
# ...

# %%
df.shape
# Out:
# (253409, 18)

# %%
df.isnull().sum()
# Out:
# Supplier             0
# customer name        0
# city                 0
# country              0
# Latitude             0
# Longitude            0
# Channel              0
# Sub-channel          0
# Product Name         0
# Product Class        0
# Quantity             0
# Price                0
# Sales                0
# Month                0
# Year                 0
# Name of Sales Rep    0
# Manager              0
# Sales Team           0
# dtype: int64

# %%
df=df.drop('Latitude',axis=1)

# %%
df
# Out:
#                                      customer name           city  country  \
# 0                          Zieme, Doyle and Kunze          Lublin   Poland
# 1                                       Feest PLC         Świecie   Poland
# 2             Medhurst-Beer Pharmaceutical Limited         Rybnik   Poland
# 3                            Barton Ltd Pharma Plc        Czeladź   Poland
# 4                             Keeling LLC Pharmacy        Olsztyn   Poland
# ...                                            ...            ...      ...
# 253404  Koch, Borer and Hagenes Pharmaceutical Ltd           Lauf  Germany
# 253405                 Hane Ltd Pharmaceutical Ltd        Aichach  Germany
# 253406                      Harris-Conroy Pharmacy  Wilhelmshaven  Germany
# 253407                      Balistreri Group Pharm      Böblingen  Germany
# 253408              Heathcote, Kovacek and Parker             Hof  Germany
#
#         Longitude   Channel  Sub-channel            Product Name  \
# ...

# %%
import seaborn as sns
sns.pairplot(df[['Longitude','city','country']])

# %%
x=df.drop(['Month','Year'],axis=1)

# %%
x
# Out:
#                                      customer name           city  country  \
# 0                          Zieme, Doyle and Kunze          Lublin   Poland
# 1                                       Feest PLC         Świecie   Poland
# 2             Medhurst-Beer Pharmaceutical Limited         Rybnik   Poland
# 3                            Barton Ltd Pharma Plc        Czeladź   Poland
# 4                             Keeling LLC Pharmacy        Olsztyn   Poland
# ...                                            ...            ...      ...
# 253404  Koch, Borer and Hagenes Pharmaceutical Ltd           Lauf  Germany
# 253405                 Hane Ltd Pharmaceutical Ltd        Aichach  Germany
# 253406                      Harris-Conroy Pharmacy  Wilhelmshaven  Germany
# 253407                      Balistreri Group Pharm      Böblingen  Germany
# 253408              Heathcote, Kovacek and Parker             Hof  Germany
#
#         Longitude   Channel  Sub-channel            Product Name  \
# ...

# %%
y=df['Month']

# %%
y
# Out:
# 0          January
# 1          January
# 2          January
# 3          January
# 4          January
#             ...
# 253404    December
# 253405    December
# 253406    December
# 253407    December
# 253408    December
# Name: Month, Length: 253409, dtype: object

# %%
import sklearn.cluster as cluster

# %%
kmeans = cluster.KMeans(n_clusters=5)#k=5

# %%
kmeans = kmeans.fit(df[['Price','Sales']])

# %%
kmeans.cluster_centers_
# Out:
# array([[4.10029605e+02, 2.56113382e+04],
#        [5.89976190e+02, 1.56947421e+07],
#        [5.59295019e+02, 4.84960623e+06],
#        [5.71000000e+02, 6.06088000e+07],
#        [5.59731402e+02, 1.02142270e+06]])

# %%
df['clusters']=kmeans.labels_

# %%
df['clusters']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 253404    0
# 253405    0
# 253406    0
# 253407    0
# 253408    0
# Name: clusters, Length: 253409, dtype: int32

# %%
df.head(15)
# Out:
#                              customer name               city country  \
# 0                  Zieme, Doyle and Kunze              Lublin  Poland
# 1                               Feest PLC             Świecie  Poland
# 2     Medhurst-Beer Pharmaceutical Limited             Rybnik  Poland
# 3                    Barton Ltd Pharma Plc            Czeladź  Poland
# 4                     Keeling LLC Pharmacy            Olsztyn  Poland
# 5       Runte-Marquardt Pharmaceutical Ltd             Olecko  Poland
# 6           Blick, Pacocha and Schowalter          Inowrocław  Poland
# 7                    Leuschke PLC Pharmacy          Ciechanów  Poland
# 8            Miller-Satterfield Pharma Plc            Nidzica  Poland
# 9            Bashirian-Kassulke Pharma Plc             Kraków  Poland
# 10                       Wolff Group Pharm              Gubin  Poland
# 11   Denesik, Walter and Beatty Pharma Plc  Ostrów Mazowiecka  Poland
# ...

# %%
df['clusters'].value_counts()
# Out:
# clusters
# 0    249824
# 4      3280
# 2       261
# 1        42
# 3         2
# Name: count, dtype: int64

# %%
seaborn.scatterplot(x='Price',y='Sales',hue='clusters',data=df)
# Out:
# <Axes: xlabel='Price', ylabel='Sales'>

# %%
from sklearn.cluster import KMeans

# %%
k_range=range(1,10)
wcss=[]

# %%
for k in k_range:
    km = KMeans(n_clusters=k)
    km.fit(df[['Price','Sales']])
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [3.098014333455502e+16,
#  1.6065199013232094e+16,
#  1.1078662272312896e+16,
#  6242001076303462.0,
#  4122546960694703.5,
#  3361748578779305.0,
#  2236984049731214.2,
#  1821107909563392.0,
#  1485200769482285.2]

# %%
plt.xlabel('Number of clusters (K)')
plt.ylabel('Sum of squared error')
plt.plot(k_range,wcss)
plt.title('pharmacy sales datas')
# Out:
# Text(0.5, 1.0, 'pharmacy sales datas')

# %%
k_range=range(1,20)
wcss2=[]

# %%
for k in k_range:
    km = KMeans(n_clusters=k)
    km.fit(df[['Longitude','Quantity']])
    wcss2.append(km.inertia_)

# %%
wcss2
# Out:
# [140757576752.02557,
#  71541119788.84421,
#  45736127754.30291,
#  29666045202.11706,
#  18484407088.507156,
#  13767502272.294096,
#  8995096076.61709,
#  6968769717.05194,
#  6462127585.905759,
#  4628694702.450704,
#  3891547933.6649756,
#  3361913903.0036106,
#  2848307306.8209786,
#  2302517206.972914,
#  2155889517.803902,
#  2033455696.4320605,
#  1822399432.7517803,
#  1493655661.7172494,
#  1336519444.6522405]

# %%
plt.xlabel('Number of clusters (K)')
plt.ylabel('Sum of squared error')
plt.plot(k_range,wcss2)

# %%
kmeans2 = cluster.KMeans(n_clusters = 4)

# %%
kmeans2 = kmeans2.fit(df[['Price','Sales']])

# %%
kmeans2.cluster_centers_
# Out:
# array([[4.11238635e+02, 3.13393711e+04],
#        [5.47800000e+02, 1.22839451e+07],
#        [5.69682014e+02, 2.01097630e+06],
#        [5.71000000e+02, 6.06088000e+07]])

# %%
df['Sales_clusters'] = kmeans2.labels_

# %%
df['Sales_clusters'].value_counts()
# Out:
# Sales_clusters
# 0    251939
# 2      1388
# 1        80
# 3         2
# Name: count, dtype: int64

# %%
seaborn.scatterplot(x='Sales', y='Price',hue='Sales_clusters',data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Price'>
